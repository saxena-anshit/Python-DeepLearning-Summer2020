# %%
from sklearn.datasets import fetch_20newsgroups
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
import keras
from keras.layers import Embedding, Dense, LSTM, GRU
from keras.models import Sequential
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit
import string
# Out:
# Using TensorFlow backend.

# %%
categories = ['comp.sys.mac.hardware',
 'comp.windows.x',
 'misc.forsale',
 'rec.autos',
'soc.religion.christian',
 'talk.politics.guns',
 'talk.politics.mideast']
# Prepare train and test data
data = fetch_20newsgroups(shuffle=True, subset='train', categories=categories)
test = fetch_20newsgroups(shuffle=True, subset='test', categories=categories)
news, news_topics, _classes = data.data, data.target, data.target_names

# %%
# Tokenize the sentences into words (2000)
nb_words = 10000
tokenizer = Tokenizer(num_words=nb_words)
tokenizer.fit_on_texts(news)
sequences = Tokenizer.texts_to_sequences(tokenizer, news)

# %%
word_index = tokenizer.word_index
print('Found %s unique tokens.' % len(word_index))
# Out:
# Found 55199 unique tokens.

# %%
max_seq_len = 1000
input_data = pad_sequences(sequences, maxlen=max_seq_len)
one_hot_labels = keras.utils.to_categorical(news_topics)

print('Shape of data tensor:', input_data.shape)
print('Shape of label tensor:', one_hot_labels.shape)
# Out:
# Shape of data tensor: (4059, 1000)
# Shape of label tensor: (4059, 7)

# %%
Xtrain, Xvalid, ytrain, yvalid = train_test_split(input_data, one_hot_labels, test_size=0.2)
len(word_index)
# Out:
# 55199

# %%
embedding_vector_length = 64
model = Sequential()
# add embedding layer
model.add(Embedding(len(word_index), embedding_vector_length, input_length=max_seq_len, init='glorot_normal', W_regularizer=keras.regularizers.l2(0.01)))
# add this to run without embedding layer
# model.add(LSTM(100, return_sequences=True,input_shape=(1, max_seq_len)))
model.add(LSTM(100, dropout_W=0.25))
model.add(Dense(7, activation='softmax'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model.summary())
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: UserWarning: Update your `Embedding` call to the Keras 2 API: `Embedding(55199, 64, input_length=1000, embeddings_initializer="glorot_normal", embeddings_regularizer=<keras.reg...)`
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: Update your `LSTM` call to the Keras 2 API: `LSTM(100, dropout=0.25)`
#   """
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 1000, 64)          3532736
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 100)               66000
# _________________________________________________________________
# dense_2 (Dense)              (None, 7)                 707
# =================================================================
# Total params: 3,599,443
# Trainable params: 3,599,443
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
Xtrain.shape, ytrain.shape, Xvalid.shape, yvalid.shape
# import numpy as np
# Xtrain = np.reshape(Xtrain, (Xtrain.shape[0], 1 , Xtrain.shape[1]))
# Xvalid = np.reshape(Xvalid, (Xvalid.shape[0], 1, Xvalid.shape[1]))
# ytrain = np.reshape(ytrain, (ytrain.shape[0], 1, ytrain.shape[1]))
# yvalid = np.reshape(yvalid, (yvalid.shape[0], 1, yvalid.shape[1]))
# Out:
# ((3247, 1000), (3247, 7), (812, 1000), (812, 7))

# %%
history=model.fit(Xtrain, ytrain, epochs=20,verbose=True, validation_data=(Xvalid,yvalid), batch_size=64)
# Out:
# Train on 3247 samples, validate on 812 samples
# Epoch 1/20
# 3247/3247 [==============================] - 63s 19ms/step - loss: 0.3102 - accuracy: 0.9175 - val_loss: 0.3635 - val_accuracy: 0.8962
# Epoch 2/20
# 3247/3247 [==============================] - 62s 19ms/step - loss: 0.3148 - accuracy: 0.9197 - val_loss: 0.4015 - val_accuracy: 0.8936
# Epoch 3/20
# 3247/3247 [==============================] - 62s 19ms/step - loss: 0.3189 - accuracy: 0.9210 - val_loss: 0.3650 - val_accuracy: 0.9011
# Epoch 4/20
# 3247/3247 [==============================] - 62s 19ms/step - loss: 0.3277 - accuracy: 0.9216 - val_loss: 0.3932 - val_accuracy: 0.8906
# Epoch 5/20
# 3247/3247 [==============================] - 62s 19ms/step - loss: 0.2939 - accuracy: 0.9322 - val_loss: 0.3540 - val_accuracy: 0.9066
# Epoch 6/20
# 3247/3247 [==============================] - 62s 19ms/step - loss: 0.2909 - accuracy: 0.9424 - val_loss: 0.4336 - val_accuracy: 0.8895
# Epoch 7/20
# 3247/3247 [==============================] - 63s 19ms/step - loss: 0.3446 - accuracy: 0.9256 - val_loss: 0.3656 - val_accuracy: 0.9027
# Epoch 8/20
# 3247/3247 [==============================] - 62s 19ms/step - loss: 0.2697 - accuracy: 0.9488 - val_loss: 0.3287 - val_accuracy: 0.9171
# Epoch 9/20
# 3247/3247 [==============================] - 62s 19ms/step - loss: 0.2742 - accuracy: 0.9505 - val_loss: 0.3824 - val_accuracy: 0.9117
# Epoch 10/20
# 3247/3247 [==============================] - 63s 19ms/step - loss: 0.3024 - accuracy: 0.9489 - val_loss: 0.3955 - val_accuracy: 0.9078
# Epoch 11/20
# 3247/3247 [==============================] - 63s 19ms/step - loss: 0.2769 - accuracy: 0.9534 - val_loss: 0.3696 - val_accuracy: 0.9138
# Epoch 12/20
# 3247/3247 [==============================] - 66s 20ms/step - loss: 0.3019 - accuracy: 0.9524 - val_loss: 0.4264 - val_accuracy: 0.9113
# Epoch 13/20
# 3247/3247 [==============================] - 62s 19ms/step - loss: 0.2875 - accuracy: 0.9601 - val_loss: 0.3722 - val_accuracy: 0.9177
# Epoch 14/20
# 3247/3247 [==============================] - 62s 19ms/step - loss: 0.3174 - accuracy: 0.9531 - val_loss: 0.3916 - val_accuracy: 0.9275
# Epoch 15/20
# 3247/3247 [==============================] - 62s 19ms/step - loss: 0.2756 - accuracy: 0.9639 - val_loss: 0.3846 - val_accuracy: 0.9166
# Epoch 16/20
# 3247/3247 [==============================] - 62s 19ms/step - loss: 0.3076 - accuracy: 0.9568 - val_loss: 0.4275 - val_accuracy: 0.9254
# Epoch 17/20
# 3247/3247 [==============================] - 62s 19ms/step - loss: 0.3230 - accuracy: 0.9560 - val_loss: 0.4415 - val_accuracy: 0.9094
# Epoch 18/20
# 3247/3247 [==============================] - 62s 19ms/step - loss: 0.2830 - accuracy: 0.9651 - val_loss: 0.4514 - val_accuracy: 0.9129
# Epoch 19/20
# 3247/3247 [==============================] - 62s 19ms/step - loss: 0.2793 - accuracy: 0.9656 - val_loss: 0.4032 - val_accuracy: 0.9120
# Epoch 20/20
# 3247/3247 [==============================] - 62s 19ms/step - loss: 0.3244 - accuracy: 0.9514 - val_loss: 0.3882 - val_accuracy: 0.9217

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Train and validation accuracy')
plt.xlabel('Number of epochs')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Train and validation loss')
plt.xlabel('Number of epochs')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()
